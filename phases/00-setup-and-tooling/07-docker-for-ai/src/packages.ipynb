# %% [markdown]
# # <br><center>**Test Out Packages**</center>

# %%
from qdrant_client import QdrantClient

client = QdrantClient(host='qdrant', port=6333)
print(client.get_collections())
# Out:
# collections=[]
