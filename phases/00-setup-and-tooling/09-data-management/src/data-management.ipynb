# %% [markdown]
# # <br><center>**Data Management – Lecture**</center>

# %%
from datasets import load_dataset

ds = load_dataset('stanfordnlp/imdb')
print(ds)
print(ds['train'][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     unsupervised: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
# })
# ...

# %%
ds = load_dataset('wikimedia/wikipedia', '20231101.en', split='train', streaming=True)

for idx, example in enumerate(ds):
    print(example['title'])
    if idx > 4:
        break

# %%
ds = load_dataset('stanfordnlp/imdb', split='train')

ds.to_csv('imdb_train.csv')
ds.to_json('imdb_train.json')
ds.to_parquet('imdb_train.parquet')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 33432823

# %%
ds = load_dataset('stanfordnlp/imdb', split='train')

split = ds.train_test_split(test_size=0.2, seed=1000)
train_val = split['train'].train_test_split(test_size=0.125, seed=1000)

train_ds = train_val['train']
val_ds = train_val['test']
test_ds = split['test']

print(f'Train: {len(train_ds)}, Val: {len(val_ds)}, Test: {len(test_ds)}')
# Out:
# Train: 17500, Val: 2500, Test: 5000
